# %%
def checkIfNot(*args):
    for x in args:
        if not(isinstance(x, (int, float))):
            return False
    return True

def addAll(*args):
    s = 0
    for x in args:
        s+=x
    return s

myName = "Python"
